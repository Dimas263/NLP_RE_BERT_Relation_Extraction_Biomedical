# %% [markdown]
# # **Summary BIOBERT and BIONLP For Relation Extraction In Biomedical Plant-Disease**

# %% [markdown]
# # **Connect Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Python Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# # **Result**

# %%
pd.read_excel("/content/drive/MyDrive/bert_relation_extraction/Relation Extraction Summary.xlsx", sheet_name="Uji Coba-3").fillna("")
# Out:
#                             Model Input            Unnamed: 1  \
# 0                         Learning Rate
# 1                   Other Learning Rate
# 2                            Batch Size
# 3                           Total Epoch
# 4                               Iterasi
# 5                           Total Steps
# 6                               Dropout
# 7                            Epoch Ke -
# 8                             Step Ke -
# 9                            Train Loss
# 10                             Dev Loss
# 11                             Accuracy
# 12                            Micro F-1
# 13                            Macro F-1
# 14                            Precision      Cause Of Disease
# 15                                       Treatment Of Disease
# 16                                                   Negative
# 17                                                Association
# 18                                              Macro Average
# ...

# %% [markdown]
# # **BioBert**

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True

biobert_train = mpimg.imread("/content/drive/MyDrive/bert_relation_extraction/output/visualization/biobert-train.png")
biobert_dev = mpimg.imread("/content/drive/MyDrive/bert_relation_extraction/output/visualization/biobert-dev.png")

plt.subplot(1, 2, 1)
plt.imshow(biobert_train)
plt.subplot(1, 2, 2)
plt.imshow(biobert_dev)

# %% [markdown]
# # **BiomedNLP PubMedBERT**

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True

bionlp_train = mpimg.imread("/content/drive/MyDrive/bert_relation_extraction/output/visualization/BiomedNLP-PubMedBERT-train.png")
bionlp_dev = mpimg.imread("/content/drive/MyDrive/bert_relation_extraction/output/visualization/BiomedNLP-PubMedBERT-dev.png")

plt.subplot(1, 2, 1)
plt.imshow(bionlp_train)
plt.subplot(1, 2, 2)
plt.imshow(bionlp_dev)
